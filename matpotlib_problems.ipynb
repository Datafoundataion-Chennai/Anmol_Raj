# %%
# 📝 Problem 1: Dual Y-Axis Plot - Stock Price & Trading Volume
# 📊 Scenario: You are analyzing a stock’s performance over 10 days. You need to visualize the closing price and trading volume in a single plot using dual Y-axes.
# 📌 Instructions:
# - Use closing price (stock_price) on the left Y-axis. - Use trading volume (trading_volume) on the right Y-axis. - Format the plot with different line styles, markers, and colors. - Add proper titles, labels, legends, and grid lines.
# days = np.arange(1, 11)  
# stock_price = [150, 152, 149, 155, 160, 162, 158, 165, 170, 175]  # In USD
# trading_volume = [1.2, 1.4, 1.1, 1.8, 2.0, 2.5, 2.2, 2.7, 3.0, 3.5]  # In million shares
# ✅ Concepts Covered: twinx(), dual Y-axes, customization, legends
# ⏳ Estimated Time: 30 minutes
# ________________________________________

import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

days = np.arange(1, 11)
stock_price = [150, 152, 149, 155, 160, 162, 158, 165, 170, 175]
trading_volume = [1.2, 1.4, 1.1, 1.8, 2.0, 2.5, 2.2, 2.7, 3.0, 3.5]

fig, ax0 = plt.subplots(figsize=(10, 6))

ax0.plot(days, stock_price, marker = 'o', color = "red", linestyle = "--", label = "Stock Price (USD)")
ax0.legend()
ax0.grid(True)

ax1 = ax0.twinx()
ax1.plot(days, trading_volume, marker = 's', color = "blue", linestyle = "--", label = "Trading Volume (Million Shares)")
ax0.set_title("Closing Stock price Vs Trading Volume")
ax1.legend()
ax1.grid(True)

plt.tight_layout()
plt.show()

# %%
# 📝 Problem 2: Stacked Bar Chart - Monthly Expenses Comparison
# 📊 Scenario: You are tracking your monthly expenses across different categories (Rent, Food, Entertainment, and Transport) for the first 6 months of the year. Create a stacked bar chart to compare the expenses for each category over time.
# 📌 Instructions:
# - Create a stacked bar chart to visualize monthly expenses. - Use different colors for each expense category. - Add a legend, labels, and a title to improve readability.
# months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun"]
# rent = [1200, 1200, 1200, 1200, 1250, 1250]
# food = [400, 420, 450, 480, 500, 520]
# entertainment = [150, 200, 220, 180, 250, 300]
# transport = [100, 120, 130, 110, 140, 160]
# ✅ Concepts Covered: bar(), stacking bars, adding legends, colors
# ⏳ Estimated Time: 30 minutes
# ________________________________________
import matplotlib.pyplot as plt
import numpy as np

months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun"]
rent = [1200, 1200, 1200, 1200, 1250, 1250]
food = [400, 420, 450, 480, 500, 520]
entertainment = [150, 200, 220, 180, 250, 300]
transport = [100, 120, 130, 110, 140, 160]

plt.figure(figsize = (10, 6))
plt.bar(months, rent, label = "Rent", color = "red")
plt.bar(months, food, label = "Food", color = "blue")
plt.bar(months, entertainment, label = "Entertainment", bottom = np.array(rent) + np.array(food), color = "yellow")
plt.bar(months, transport, label = "Transport", bottom = np.array(rent) + np.array(food) + np.array(entertainment), color = "purple")

plt.xlabel("Months")
plt.ylabel("Expenses")
plt.title("Monthly Expenses Comparison")
plt.legend()
plt.grid(axis = "y")
plt.show()

# %%
# 📝 Problem 3: Subplots - COVID-19 Cases & Vaccination Progress
# 📊 Scenario: You have weekly COVID-19 cases and vaccination rates for 8 weeks. Visualize both metrics using two subplots in one figure.
# 📌 Instructions:
# - The first subplot should display weekly cases using a line plot with markers. - The second subplot should show vaccination progress (%) using a bar chart. - Use different colors, labels, and titles for both subplots. - Apply tight_layout() to prevent overlap.
# weeks = np.arange(1, 9)  
# covid_cases = [500, 700, 1200, 2000, 3000, 4500, 6000, 8000]  
# vaccination_rate = [5, 10, 20, 35, 50, 65, 75, 85]  # In percentage
# ✅ Concepts Covered: subplots(), multiple charts, formatting
# ⏳ Estimated Time: 30 minutes
# ________________________________________

import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

weeks = np.arange(1, 9)  
covid_cases = [500, 700, 1200, 2000, 3000, 4500, 6000, 8000] 
vaccination_rate = [5, 10, 20, 35, 50, 65, 75, 85]

plt.plot(weeks, covid_cases, marker = "o", linestyle = "--", color = "red", linewidth = 2, markersize = 8, label = "Covid Cases")
plt.xlabel("No. of Weeks")
plt.ylabel("Covid-19 Cases")
plt.title("weekly COVID-19 cases for 8 Weeks")
plt.legend()
plt.grid(True)
plt.show()

plt.bar(weeks, vaccination_rate, color = ["violet", "blue", "green", "yellow", "purple", "pink", "magenta", "indigo"])
plt.xlabel("No. of Weeks")
plt.ylabel("Vaccination rate")
plt.title("Weekly COVID-19 Case Vs Vacination rates")
plt.show()
